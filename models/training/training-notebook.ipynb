# %%
# Install Ultralytics (YOLO) if not already installed
# %pip install ultralytics
import ultralytics
ultralytics.checks()

import os
import shutil
from ultralytics import YOLO

# --- PATH CONFIGURATION (Your original paths) ---
BASE = "/kaggle/working"
DATASET = "/kaggle/working/space-dataset"

# Make sure these input paths exist in your Kaggle environment
TRAIN_SRC = "/kaggle/input/duality-ai/hackathon2_train_2/train_2"
TEST_SRC = "/kaggle/input/duality-ai/Hackathon2_test1/test1"

# --- DATASET SETUP ---
if os.path.exists(DATASET):
    shutil.rmtree(DATASET)
os.makedirs(DATASET, exist_ok=True)

print("📂 TRAIN source:", TRAIN_SRC)
print("📂 TEST source (external):", TEST_SRC)

print("\n📁 Creating YOLO train/val structure...")

# Copying train and val data to the working directory
shutil.copytree(f"{TRAIN_SRC}/train2", f"{DATASET}/train")
shutil.copytree(f"{TRAIN_SRC}/val2", f"{DATASET}/val")

print("✅ TRAIN and VAL copied successfully!")

print("\n⚠️ TEST will NOT be copied (to avoid disk full).")
print(" YOLO will read test images directly from:", f"{TEST_SRC}/images")

classes = [
    "OxygenTank",
    "NitrogenTank",
    "FirstAidBox",
    "FireAlarm",
    "SafetySwitchPanel",
    "EmergencyPhone",
    "FireExtinguisher"
]

# Create classes.txt (Optional for training, but good for reference)
with open(f"{DATASET}/classes.txt", "w") as f:
    f.write("\n".join(classes))
print("✔ classes.txt created")

# --- YAML CREATION ---
yaml_path = f"{DATASET}/yolo_params.yaml"
yaml_content = f"""
path: {DATASET}
train: train/images
val: val/images

# test set is external:
test: {TEST_SRC}/images

nc: {len(classes)}
names: {classes}
"""

with open(yaml_path, "w") as f:
    f.write(yaml_content)

print(f"✔ yolo_params.yaml created at: {yaml_path}")

# --- YOLO V11 M TRAINING ---
print("\n🚀 Starting YOLO11m Training...")

# Load the YOLO v11 Medium model
# Ultralytics will automatically download 'yolo11m.pt' if not present


# Train the model
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6582.3/8062.4 GB disk)
# 📂 TRAIN source: /kaggle/input/duality-ai/hackathon2_train_2/train_2
# 📂 TEST source (external): /kaggle/input/duality-ai/Hackathon2_test1/test1
#
# 📁 Creating YOLO train/val structure...
# ✅ TRAIN and VAL copied successfully!
#
# ⚠️ TEST will NOT be copied (to avoid disk full).
#  YOLO will read test images directly from: /kaggle/input/duality-ai/Hackathon2_test1/test1/images
# ✔ classes.txt created
# ✔ yolo_params.yaml created at: /kaggle/working/space-dataset/yolo_params.yaml
#
# 🚀 Starting YOLO11m Training...

# %%
model = YOLO("yolo12m.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12m.pt to 'yolo12m.pt': 100% ━━━━━━━━━━━━ 39.0MB 227.1MB/s 0.2s0.1s<0.1s

# %%
results = model.train(
    data=yaml_path,     # Path to the dataset config we just created
    epochs=100,          # Adjust epochs as needed
    imgsz=720,          # Image size
    batch=8,
    device=[0,1],
   # Adjust batch size based on GPU memory (16 is usually safe for 'm' on T4)
    project="/kaggle/working/runs/train", # Explicit path to save results
    name="yolo11m_space_run",             # Name of this specific run
    exist_ok=True,
    patience = 10 # Overwrite existing experiment with same name
)

print("🏆 Training Complete. Best model saved in /kaggle/working/runs/train/yolo11m_space_run/weights/")
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#                                                        CUDA:1 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/space-dataset/yolo_params.yaml, degrees=0.0, deterministic=True, device=0,1, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=720, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11m_space_run, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs/train, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/train/yolo11m_space_run, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1416421  ultralytics.nn.modules.head.Detect           [7, [256, 512, 512]]
# YOLOv12m summary: 292 layers, 20,142,885 parameters, 20,142,869 gradients, 67.8 GFLOPs
#
# Transferred 751/751 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 47755 /root/.config/Ultralytics/DDP/_temp_458s01fl132560517575744.py
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#                                                        CUDA:1 (Tesla T4, 15095MiB)
# Overriding model.yaml nc=80 with nc=7
# Transferred 745/751 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# WARNING ⚠️ imgsz=[720] must be multiple of max stride 32, updating to [736]
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2846.5±1675.9 MB/s, size: 3057.2 KB)
# train: Scanning /kaggle/working/space-dataset/train/labels.cache... 1767 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1767/1767 30.0Mit/s 0.0ss
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2664.9±2021.1 MB/s, size: 2927.3 KB)
# val: Scanning /kaggle/working/space-dataset/val/labels.cache... 336 images, 16 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 336/336 1.3Mit/s 0.0ss
# Plotting labels to /kaggle/working/runs/train/yolo11m_space_run/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# Image sizes 736 train, 736 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/train/yolo11m_space_run
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.61G      1.009      1.915      1.259         30        736: 100% ━━━━━━━━━━━━ 221/221 2.4it/s 1:34<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 2.5it/s 8.3s0.3s
#                    all        336        957      0.636      0.474      0.518      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.67G      1.309      1.742      1.447         22        736: 100% ━━━━━━━━━━━━ 221/221 2.6it/s 1:24<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.6it/s 5.8s0.2s
#                    all        336        957        0.6      0.424      0.436      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.74G      1.317      1.774      1.463         19        736: 100% ━━━━━━━━━━━━ 221/221 2.7it/s 1:23<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.8it/s 5.5s0.4s
#                    all        336        957      0.597      0.444      0.478      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.81G      1.276      1.687      1.423         39        736: 100% ━━━━━━━━━━━━ 221/221 2.7it/s 1:23<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.5it/s 6.0s0.2s
#                    all        336        957      0.659      0.466      0.515      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.81G      1.246      1.578      1.408         14        736: 100% ━━━━━━━━━━━━ 221/221 2.7it/s 1:23<0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3
0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.7it/s 5.7s0.3s
#                    all        336        957      0.934      0.819      0.873      0.771
#
# 100 epochs completed in 2.535 hours.
# Optimizer stripped from /kaggle/working/runs/train/yolo11m_space_run/weights/last.pt, 40.8MB
# Optimizer stripped from /kaggle/working/runs/train/yolo11m_space_run/weights/best.pt, 40.8MB
#
# Validating /kaggle/working/runs/train/yolo11m_space_run/weights/best.pt...
# YOLOv12m summary (fused): 169 layers, 20,110,309 parameters, 0 gradients, 67.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 3.8it/s 5.6s0.3s
#                    all        336        957      0.934      0.817      0.874      0.771
#             OxygenTank        135        237       0.96      0.865      0.922      0.852
#           NitrogenTank        157        283      0.919      0.845      0.898      0.809
#            FirstAidBox         97        119      0.902      0.849      0.902      0.818
#              FireAlarm         55         57      0.924      0.854      0.914      0.836
#      SafetySwitchPanel         55         60      0.944      0.783      0.828      0.697
#         EmergencyPhone         60         69      0.964      0.779      0.837      0.656
#       FireExtinguisher         92        132      0.925      0.747      0.819      0.727
# Speed: 0.1ms preprocess, 6.2ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/train/yolo11m_space_run
# 🏆 Training Complete. Best model saved in /kaggle/working/runs/train/yolo11m_space_run/weights/

# %%
print("\n📊 Validating model performance...")
metrics = model.val() 

# Print key metrics explicitly
print("-" * 30)
print(f"✔ mAP@50 (Metric for detection):    {metrics.box.map50:.4f}")
print(f"✔ mAP@50-95 (Strict accuracy):      {metrics.box.map:.4f}")
print(f"✔ Precision:                        {metrics.box.mp:.4f}")
print(f"✔ Recall:                           {metrics.box.mr:.4f}")
print("-" * 30)

# --- 3. PREDICT ON EXTERNAL TEST SET ---
# Since you kept the test set in the input folder (to save space), we point to it here.
print(f"\n🔮 Running inference on Test Set: {TEST_SRC}/images")

test_results = model.predict(
    source=f"{TEST_SRC}/images",
    save=True,              # Save the images with bounding boxes drawn
    save_txt=True,          # Save the detection coordinates (.txt)
    conf=0.25,              # Minimum confidence to detect an object
    project="space_mission",
    name="test_predictions" ,
    # Results will be in: space_mission/test_predictions
)

print(f"✅ Testing complete! Results saved to: {BASE}/space_mission/test_predictions")
# Out:
# 📊 Validating model performance...
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12m summary (fused): 169 layers, 20,110,309 parameters, 0 gradients, 67.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4906.3±832.4 MB/s, size: 2848.2 KB)
# val: Scanning /kaggle/working/space-dataset/val/labels.cache... 336 images, 16 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 336/336 61.7Kit/s 0.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.7it/s 12.3s0.6s
#                    all        336        957      0.934      0.818      0.875      0.771
#             OxygenTank        135        237      0.964      0.865      0.922      0.853
#           NitrogenTank        157        283      0.918      0.845      0.898      0.809
#            FirstAidBox         97        119      0.902      0.849      0.901      0.818
#              FireAlarm         55         57      0.924      0.854      0.914      0.834
#      SafetySwitchPanel         55         60      0.944      0.783      0.827      0.699
#         EmergencyPhone         60         69      0.964       0.78      0.838      0.658
#       FireExtinguisher         92        132      0.925      0.747      0.822      0.728
# Speed: 0.8ms preprocess, 23.0ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
# ------------------------------
# ✔ mAP@50 (Metric for detection):    0.8746
# ✔ mAP@50-95 (Strict accuracy):      0.7713
# ✔ Precision:                        0.9345
# ✔ Recall:                           0.8176
# ------------------------------
#
# 🔮 Running inference on Test Set: /kaggle/input/duality-ai/Hackathon2_test1/test1/images
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000001_light_unclutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 75.8ms
# image 2/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000001_vdark_clutter.png: 416x736 1 OxygenTank, 2 NitrogenTanks, 2 FirstAidBoxs, 1 FireExtinguisher, 34.3ms
# image 3/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000002_dark_clutter.png: 416x736 1 OxygenTank, 34.4ms
# image 4/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000002_vlight_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 5/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000003_vdark_unclutter.png: 416x736 2 OxygenTanks, 2 SafetySwitchPanels, 34.3ms
# image 6/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000006_dark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 7/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000006_light_unclutter.png: 416x736 2 OxygenTanks, 3 NitrogenTanks, 34.3ms
# image 8/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000006_vdark_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 9/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000007_dark_clutter.png: 416x736 1 OxygenTank, 2 NitrogenTanks, 2 FirstAidBoxs, 1 FireAlarm, 1 EmergencyPhone, 1 FireExtinguisher, 34.3ms
# image 10/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000007_vdark_unclutter.png: 416x736 2 FirstAidBoxs, 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 11/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000008_light_unclutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 1 FireAlarm, 2 SafetySwitchPanels, 2 EmergencyPhones, 2 FireExtinguishers, 34.3ms
# image 12/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000008_vlight_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 13/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000010_dark_clutter.png: 416x736 3 OxygenTanks, 1 NitrogenTank, 34.3ms
# image 14/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000010_vdark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 15/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000011_light_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 16/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000011_vdark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 17/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000012_light_unclutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 4 FirstAidBoxs, 34.3ms
# image 18/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000012_vdark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 1 SafetySwitchPanel, 2 FireExtinguishers, 34.3ms
# image 19/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000013_dark_clutter.png: 416x736 3 OxygenTanks, 2 NitrogenTanks, 1 EmergencyPhone, 34.3ms
# image 20/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000014_dark_clutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 21/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000015_light_unclutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 34.4ms
# image 22/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000015_vdark_clutter.png: 416x736 5 OxygenTanks, 2 NitrogenTanks, 34.3ms
# image 23/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000016_vdark_clutter.png: 416x736 3 OxygenTanks, 1 FirstAidBox, 1 FireExtinguisher, 34.3ms
# image 24/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000018_vlight_unclutter.png: 416x736 1 FireAlarm, 34.4ms
# image 25/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000020_vdark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 34.4ms
# image 26/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000021_dark_unclutter.png: 416x736 1 EmergencyPhone, 34.3ms
# image 27/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000022_dark_unclutter.png: 416x736 (no detections), 34.3ms
# image 28/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000022_vdark_clutter.png: 416x736 1 OxygenTank, 3 NitrogenTanks, 2 FirstAidBoxs, 1 EmergencyPhone, 1 FireExtinguisher, 34.3ms
# image 29/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000023_vdark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 30/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000023_vdark_unclutter.png: 416x736 (no detections), 34.4ms
# image 31/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000025_vlight_unclutter.png: 416x736 3 OxygenTanks, 1 NitrogenTank, 34.4ms
# image 32/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000026_dark_unclutter.png: 416x736 (no detections), 34.3ms
# image 33/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000026_vdark_unclutter.png: 416x736 2 NitrogenTanks, 34.3ms
# image 34/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000027_dark_unclutter.png: 416x736 (no detections), 34.3ms
# image 35/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000029_vlight_unclutter.png: 416x736 1 FireAlarm, 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 36/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000030_vlight_unclutter.png: 416x736 1 OxygenTank, 1 FirstAidBox, 2 SafetySwitchPanels, 1 EmergencyPhone, 34.4ms
# image 37/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000031_dark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 1 SafetySwitchPanel, 34.3ms
# image 38/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000031_vlight_unclutter.png: 416x736 3 OxygenTanks, 1 FireAlarm, 1 EmergencyPhone, 34.4ms
# image 39/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000032_vdark_unclutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 40/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000032_vlight_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 41/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000033_dark_unclutter.png: 416x736 1 OxygenTank, 34.4ms
# image 42/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000033_light_unclutter.png: 416x736 2 OxygenTanks, 4 NitrogenTanks, 34.3ms
# image 43/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000033_vdark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 34.3ms
# image 44/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000034_vdark_clutter.png: 416x736 1 EmergencyPhone, 34.3ms
# image 45/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000035_light_unclutter.png: 416x736 3 OxygenTanks, 1 FireExtinguisher, 34.3ms
# image 46/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000035_vdark_clutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 47/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000036_dark_clutter.png: 416x736 2 NitrogenTanks, 34.3ms
# image 48/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000037_dark_clutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 49/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000037_dark_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 50/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000038_dark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 2 FirstAidBoxs, 1 EmergencyPhone, 2 FireExtinguishers, 34.3ms
# image 51/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000038_light_unclutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 34.4ms
# image 52/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000038_vdark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 1 FirstAidBox, 2 FireExtinguishers, 34.3ms
# image 53/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000039_dark_unclutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 34.3ms
# image 54/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000039_vlight_unclutter.png: 416x736 4 OxygenTanks, 1 NitrogenTank, 34.4ms
# image 55/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000040_dark_clutter.png: 416x736 2 OxygenTanks, 5 NitrogenTanks, 1 FirstAidBox, 1 FireExtinguisher, 34.3ms
# image 56/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000040_dark_unclutter.png: 416x736 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 57/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000042_dark_unclutter.png: 416x736 2 NitrogenTanks, 34.4ms
# image 58/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000042_vdark_unclutter.png: 416x736 4 OxygenTanks, 3 NitrogenTanks, 34.3ms
# image 59/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000043_dark_clutter.png: 416x736 3 OxygenTanks, 34.3ms
# image 60/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000044_vdark_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 61/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000045_dark_unclutter.png: 416x736 (no detections), 34.3ms
# image 62/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000045_vdark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 34.3ms
# image 63/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000045_vlight_unclutter.png: 416x736 2 OxygenTanks, 4 NitrogenTanks, 34.3ms
# image 64/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000046_vlight_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 65/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000047_dark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 66/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000047_vdark_clutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 67/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000049_dark_clutter.png: 416x736 (no detections), 34.3ms
# image 68/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000049_dark_unclutter.png: 416x736 1 OxygenTank, 34.4ms
# image 69/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000049_vdark_clutter.png: 416x736 3 OxygenTanks, 1 NitrogenTank, 1 FirstAidBox, 1 EmergencyPhone, 1 FireExtinguisher, 34.3ms
# image 70/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000050_vdark_clutter.png: 416x736 2 OxygenTanks, 34.3ms
# image 71/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000051_vdark_unclutter.png: 416x736 1 FireAlarm, 34.3ms
# image 72/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000051_vlight_unclutter.png: 416x736 1 OxygenTank, 2 NitrogenTanks, 1 FireExtinguisher, 34.3ms
# image 73/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000052_dark_clutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 74/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000052_dark_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 75/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000052_vdark_clutter.png: 416x736 2 NitrogenTanks, 34.3ms
# image 76/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000053_light_unclutter.png: 416x736 4 NitrogenTanks, 34.3ms
# image 77/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000053_vdark_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 78/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000054_vdark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 3 FirstAidBoxs, 34.3ms
# image 79/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000054_vdark_unclutter.png: 416x736 1 FireExtinguisher, 34.3ms
# image 80/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000055_vdark_clutter.png: 416x736 (no detections), 34.3ms
# image 81/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000056_vdark_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 82/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000056_vlight_unclutter.png: 416x736 1 FirstAidBox, 1 FireExtinguisher, 34.3ms
# image 83/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000058_vdark_clutter.png: 416x736 2 FirstAidBoxs, 34.3ms
# image 84/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000060_vdark_clutter.png: 416x736 2 OxygenTanks, 2 NitrogenTanks, 1 FirstAidBox, 1 SafetySwitchPanel, 1 EmergencyPhone, 1 FireExtinguisher, 34.3ms
# image 85/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000061_light_unclutter.png: 416x736 1 FireAlarm, 34.3ms
# image 86/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000061_vdark_clutter.png: 416x736 1 OxygenTank, 1 FirstAidBox, 34.4ms
# image 87/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000062_light_unclutter.png: 416x736 1 NitrogenTank, 1 FireAlarm, 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 88/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000062_vdark_unclutter.png: 416x736 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 89/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000063_vdark_clutter.png: 416x736 1 EmergencyPhone, 34.3ms
# image 90/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000064_dark_unclutter.png: 416x736 (no detections), 34.4ms
# image 91/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000064_vdark_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 92/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000064_vlight_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.4ms
# image 93/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000065_dark_clutter.png: 416x736 1 OxygenTank, 1 FirstAidBox, 34.4ms
# image 94/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000065_light_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 95/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000065_vdark_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 96/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000066_vdark_clutter.png: 416x736 1 NitrogenTank, 1 FireExtinguisher, 34.3ms
# image 97/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000067_dark_clutter.png: 416x736 1 OxygenTank, 2 NitrogenTanks, 34.3ms
# image 98/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000068_dark_clutter.png: 416x736 1 OxygenTank, 3 NitrogenTanks, 1 FirstAidBox, 34.3ms
# image 99/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000068_vdark_clutter.png: 416x736 2 OxygenTanks, 1 FireAlarm, 1 SafetySwitchPanel, 34.4ms
# image 100/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000069_dark_unclutter.png: 416x736 1 FireAlarm, 1 SafetySwitchPanel, 34.3ms
# image 101/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000069_vdark_unclutter.png: 416x736 1 FireExtinguisher, 34.4ms
# image 102/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000070_dark_clutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 103/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000070_vdark_unclutter.png: 416x736 2 EmergencyPhones, 34.3ms
# image 104/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000071_dark_clutter.png: 416x736 2 OxygenTanks, 1 FirstAidBox, 2 FireExtinguishers, 34.4ms
# image 105/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000072_dark_clutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 106/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000072_vlight_unclutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 107/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000073_vdark_clutter.png: 416x736 1 FirstAidBox, 2 FireExtinguishers, 34.3ms
# image 108/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000075_dark_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 109/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000078_dark_unclutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 110/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000078_vdark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 111/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000078_vdark_unclutter.png: 416x736 1 OxygenTank, 34.4ms
# image 112/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000079_light_unclutter.png: 416x736 1 FireExtinguisher, 34.4ms
# image 113/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000079_vdark_clutter.png: 416x736 2 OxygenTanks, 1 FireExtinguisher, 34.4ms
# image 114/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000080_dark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 34.3ms
# image 115/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000081_light_unclutter.png: 416x736 1 OxygenTank, 1 FirstAidBox, 34.3ms
# image 116/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000081_vdark_clutter.png: 416x736 2 OxygenTanks, 2 FireExtinguishers, 34.3ms
# image 117/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000083_dark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 118/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000083_vdark_clutter.png: 416x736 1 OxygenTank, 34.3ms
# image 119/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000084_dark_unclutter.png: 416x736 1 NitrogenTank, 2 FireExtinguishers, 34.3ms
# image 120/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000084_vlight_unclutter.png: 416x736 1 FireAlarm, 34.4ms
# image 121/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000085_dark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 34.3ms
# image 122/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000085_dark_unclutter.png: 416x736 3 OxygenTanks, 1 NitrogenTank, 34.4ms
# image 123/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000085_vdark_clutter.png: 416x736 1 OxygenTank, 1 FirstAidBox, 34.3ms
# image 124/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000086_dark_clutter.png: 416x736 1 OxygenTank, 34.3ms
# image 125/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000086_dark_unclutter.png: 416x736 (no detections), 34.3ms
# image 126/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000087_dark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 1 SafetySwitchPanel, 1 FireExtinguisher, 34.3ms
# image 127/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000087_light_unclutter.png: 416x736 1 EmergencyPhone, 34.4ms
# image 128/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000087_vdark_clutter.png: 416x736 2 OxygenTanks, 5 FirstAidBoxs, 1 FireExtinguisher, 34.3ms
# image 129/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000088_vdark_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 130/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000089_dark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 131/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000089_light_unclutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 132/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000090_vdark_clutter.png: 416x736 1 NitrogenTank, 1 FireExtinguisher, 34.3ms
# image 133/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000091_vlight_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 134/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000092_dark_unclutter.png: 416x736 1 OxygenTank, 2 NitrogenTanks, 34.3ms
# image 135/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000092_vdark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 136/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000094_dark_clutter.png: 416x736 1 SafetySwitchPanel, 1 EmergencyPhone, 34.4ms
# image 137/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000094_light_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 138/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000095_dark_clutter.png: 416x736 1 OxygenTank, 1 FirstAidBox, 34.3ms
# image 139/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000095_vdark_unclutter.png: 416x736 2 OxygenTanks, 34.3ms
# image 140/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000096_dark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 141/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000096_light_unclutter.png: 416x736 1 FireExtinguisher, 34.3ms
# image 142/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000098_vdark_unclutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 34.3ms
# image 143/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000099_vdark_clutter.png: 416x736 1 OxygenTank, 2 NitrogenTanks, 34.3ms
# image 144/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000100_light_unclutter.png: 416x736 4 NitrogenTanks, 34.4ms
# image 145/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000101_dark_unclutter.png: 416x736 3 OxygenTanks, 1 NitrogenTank, 34.3ms
# image 146/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000102_dark_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 147/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000104_dark_clutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 148/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000104_vlight_unclutter.png: 416x736 1 NitrogenTank, 2 FirstAidBoxs, 1 SafetySwitchPanel, 34.3ms
# image 149/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000105_dark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 150/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000105_vdark_clutter.png: 416x736 3 FireExtinguishers, 34.4ms
# image 151/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000106_dark_clutter.png: 416x736 1 OxygenTank, 34.4ms
# image 152/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000108_vdark_clutter.png: 416x736 1 OxygenTank, 1 FirstAidBox, 34.4ms
# image 153/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000109_dark_clutter.png: 416x736 (no detections), 34.4ms
# image 154/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000109_dark_unclutter.png: 416x736 2 OxygenTanks, 1 FirstAidBox, 1 SafetySwitchPanel, 34.5ms
# image 155/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000110_light_unclutter.png: 416x736 1 FireExtinguisher, 34.3ms
# image 156/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000110_vdark_unclutter.png: 416x736 3 NitrogenTanks, 34.3ms
# image 157/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000111_light_unclutter.png: 416x736 1 NitrogenTank, 34.4ms
# image 158/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000111_vlight_unclutter.png: 416x736 4 OxygenTanks, 3 NitrogenTanks, 34.3ms
# image 159/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000112_vdark_clutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 160/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000113_light_unclutter.png: 416x736 1 OxygenTank, 1 FireExtinguisher, 34.3ms
# image 161/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000113_vlight_unclutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 34.4ms
# image 162/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000114_vdark_clutter.png: 416x736 3 OxygenTanks, 2 NitrogenTanks, 2 FirstAidBoxs, 3 FireExtinguishers, 34.4ms
# image 163/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000115_light_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 164/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000116_dark_clutter.png: 416x736 1 OxygenTank, 34.4ms
# image 165/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000116_vlight_unclutter.png: 416x736 3 OxygenTanks, 1 FirstAidBox, 34.3ms
# image 166/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000117_vdark_clutter.png: 416x736 3 OxygenTanks, 3 NitrogenTanks, 2 FirstAidBoxs, 1 FireExtinguisher, 34.3ms
# image 167/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000118_vdark_clutter.png: 416x736 2 FireExtinguishers, 34.3ms
# image 168/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000118_vdark_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 169/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000119_dark_clutter.png: 416x736 2 NitrogenTanks, 34.4ms
# image 170/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000120_dark_unclutter.png: 416x736 3 NitrogenTanks, 34.3ms
# image 171/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000120_light_unclutter.png: 416x736 1 FireAlarm, 34.3ms
# image 172/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000120_vdark_clutter.png: 416x736 1 FireExtinguisher, 34.3ms
# image 173/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000121_light_unclutter.png: 416x736 4 OxygenTanks, 6 NitrogenTanks, 4 FirstAidBoxs, 2 FireAlarms, 2 SafetySwitchPanels, 1 EmergencyPhone, 1 FireExtinguisher, 34.3ms
# image 174/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000121_vdark_unclutter.png: 416x736 3 OxygenTanks, 1 NitrogenTank, 34.3ms
# image 175/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000123_dark_clutter.png: 416x736 1 EmergencyPhone, 34.4ms
# image 176/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000123_vdark_unclutter.png: 416x736 1 FireExtinguisher, 34.3ms
# image 177/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000124_dark_clutter.png: 416x736 1 EmergencyPhone, 34.3ms
# image 178/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000125_vlight_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 179/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000126_dark_clutter.png: 416x736 2 OxygenTanks, 34.3ms
# image 180/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000126_vlight_unclutter.png: 416x736 2 OxygenTanks, 2 NitrogenTanks, 1 FirstAidBox, 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 181/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000130_dark_unclutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 182/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000130_vdark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 183/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000130_vdark_unclutter.png: 416x736 3 OxygenTanks, 34.3ms
# image 184/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000131_dark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 1 FireExtinguisher, 34.4ms
# image 185/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000132_vdark_unclutter.png: 416x736 1 FirstAidBox, 2 SafetySwitchPanels, 34.3ms
# image 186/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000133_dark_unclutter.png: 416x736 1 OxygenTank, 1 FireExtinguisher, 34.4ms
# image 187/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000133_light_unclutter.png: 416x736 1 OxygenTank, 1 SafetySwitchPanel, 34.3ms
# image 188/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000134_vdark_unclutter.png: 416x736 (no detections), 34.3ms
# image 189/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000134_vlight_unclutter.png: 416x736 1 NitrogenTank, 2 FirstAidBoxs, 34.3ms
# image 190/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000135_dark_unclutter.png: 416x736 1 OxygenTank, 1 FireExtinguisher, 34.3ms
# image 191/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000135_light_unclutter.png: 416x736 1 SafetySwitchPanel, 1 EmergencyPhone, 1 FireExtinguisher, 34.3ms
# image 192/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000135_vdark_clutter.png: 416x736 1 FirstAidBox, 1 FireExtinguisher, 34.3ms
# image 193/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000136_vdark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 34.3ms
# image 194/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000137_dark_clutter.png: 416x736 2 OxygenTanks, 2 NitrogenTanks, 3 FirstAidBoxs, 3 FireExtinguishers, 34.3ms
# image 195/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000137_dark_unclutter.png: 416x736 3 OxygenTanks, 3 NitrogenTanks, 34.3ms
# image 196/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000138_dark_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 197/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000138_vdark_clutter.png: 416x736 1 OxygenTank, 2 NitrogenTanks, 1 FirstAidBox, 1 FireExtinguisher, 34.3ms
# image 198/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000138_vlight_unclutter.png: 416x736 1 OxygenTank, 2 FireAlarms, 1 EmergencyPhone, 2 FireExtinguishers, 34.3ms
# image 199/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000139_dark_clutter.png: 416x736 1 NitrogenTank, 2 SafetySwitchPanels, 4 FireExtinguishers, 34.3ms
# image 200/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000139_vdark_clutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 201/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000140_dark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 202/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000140_light_unclutter.png: 416x736 1 OxygenTank, 1 FirstAidBox, 34.3ms
# image 203/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000140_vdark_clutter.png: 416x736 1 FirstAidBox, 1 FireExtinguisher, 34.3ms
# image 204/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000140_vdark_unclutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 205/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000141_vdark_unclutter.png: 416x736 1 OxygenTank, 34.4ms
# image 206/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000142_dark_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 207/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000142_vdark_clutter.png: 416x736 1 OxygenTank, 34.3ms
# image 208/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000143_vdark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 209/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000144_vdark_clutter.png: 416x736 2 OxygenTanks, 2 NitrogenTanks, 2 FirstAidBoxs, 1 SafetySwitchPanel, 1 FireExtinguisher, 34.3ms
# image 210/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000144_vdark_unclutter.png: 416x736 1 EmergencyPhone, 34.3ms
# image 211/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000145_light_unclutter.png: 416x736 3 OxygenTanks, 1 FireAlarm, 2 EmergencyPhones, 34.4ms
# image 212/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000145_vdark_unclutter.png: 416x736 2 EmergencyPhones, 34.3ms
# image 213/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000146_dark_clutter.png: 416x736 2 OxygenTanks, 3 NitrogenTanks, 2 FirstAidBoxs, 1 SafetySwitchPanel, 1 EmergencyPhone, 1 FireExtinguisher, 34.3ms
# image 214/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000146_light_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 215/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000146_vdark_unclutter.png: 416x736 (no detections), 34.3ms
# image 216/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000147_vdark_unclutter.png: 416x736 4 OxygenTanks, 1 FireExtinguisher, 34.3ms
# image 217/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000149_dark_clutter.png: 416x736 1 OxygenTank, 1 FirstAidBox, 34.3ms
# image 218/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000149_vdark_unclutter.png: 416x736 (no detections), 34.3ms
# image 219/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000151_vlight_unclutter.png: 416x736 1 FireAlarm, 34.3ms
# image 220/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000152_vlight_unclutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 34.4ms
# image 221/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000153_light_unclutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 222/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000153_vdark_clutter.png: 416x736 1 NitrogenTank, 1 SafetySwitchPanel, 1 FireExtinguisher, 34.4ms
# image 223/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000154_light_unclutter.png: 416x736 1 FireAlarm, 34.3ms
# image 224/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000154_vlight_unclutter.png: 416x736 1 FireAlarm, 34.4ms
# image 225/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000155_light_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 226/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000155_vdark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 34.3ms
# image 227/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000155_vlight_unclutter.png: 416x736 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 228/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000156_dark_unclutter.png: 416x736 1 SafetySwitchPanel, 1 EmergencyPhone, 34.4ms
# image 229/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000156_vlight_unclutter.png: 416x736 1 OxygenTank, 2 FirstAidBoxs, 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 230/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000157_dark_clutter.png: 416x736 2 OxygenTanks, 1 FirstAidBox, 2 FireExtinguishers, 34.3ms
# image 231/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000158_dark_clutter.png: 416x736 1 NitrogenTank, 34.4ms
# image 232/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000158_vlight_unclutter.png: 416x736 5 OxygenTanks, 4 NitrogenTanks, 34.3ms
# image 233/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000159_vdark_unclutter.png: 416x736 3 OxygenTanks, 34.3ms
# image 234/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000160_light_unclutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 235/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000160_vdark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 236/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000160_vlight_unclutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 237/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000161_vlight_unclutter.png: 416x736 1 NitrogenTank, 1 FireExtinguisher, 34.3ms
# image 238/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000162_vdark_clutter.png: 416x736 3 OxygenTanks, 3 NitrogenTanks, 1 FireExtinguisher, 34.3ms
# image 239/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000162_vdark_unclutter.png: 416x736 3 NitrogenTanks, 34.3ms
# image 240/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000162_vlight_unclutter.png: 416x736 1 OxygenTank, 3 NitrogenTanks, 34.3ms
# image 241/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000164_dark_unclutter.png: 416x736 1 OxygenTank, 1 FireExtinguisher, 34.4ms
# image 242/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000164_light_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 243/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000164_vdark_unclutter.png: 416x736 3 NitrogenTanks, 34.3ms
# image 244/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000165_vlight_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 245/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000167_vdark_unclutter.png: 416x736 3 NitrogenTanks, 34.3ms
# image 246/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000168_dark_unclutter.png: 416x736 1 FirstAidBox, 1 SafetySwitchPanel, 34.3ms
# image 247/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000168_vlight_unclutter.png: 416x736 1 OxygenTank, 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 248/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000169_light_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 249/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000169_vdark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 250/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000170_vdark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 251/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000170_vdark_unclutter.png: 416x736 1 NitrogenTank, 1 FireExtinguisher, 34.3ms
# image 252/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000170_vlight_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 253/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000171_dark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 1 FirstAidBox, 1 FireExtinguisher, 34.3ms
# image 254/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000171_vlight_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 255/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000172_light_unclutter.png: 416x736 3 OxygenTanks, 3 NitrogenTanks, 34.3ms
# image 256/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000172_vdark_clutter.png: 416x736 3 OxygenTanks, 3 NitrogenTanks, 3 FirstAidBoxs, 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 257/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000173_light_unclutter.png: 416x736 2 NitrogenTanks, 3 SafetySwitchPanels, 34.4ms
# image 258/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000173_vdark_clutter.png: 416x736 2 NitrogenTanks, 1 FirstAidBox, 1 FireExtinguisher, 34.4ms
# image 259/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000173_vdark_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 260/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000175_dark_unclutter.png: 416x736 (no detections), 34.3ms
# image 261/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000175_vlight_unclutter.png: 416x736 2 NitrogenTanks, 34.3ms
# image 262/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000176_vlight_unclutter.png: 416x736 2 FireExtinguishers, 34.3ms
# image 263/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000177_vdark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 264/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000178_dark_unclutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 265/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000179_dark_clutter.png: 416x736 1 FireExtinguisher, 34.3ms
# image 266/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000179_dark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 267/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000181_dark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 268/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000181_vlight_unclutter.png: 416x736 2 OxygenTanks, 3 NitrogenTanks, 34.3ms
# image 269/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000182_vlight_unclutter.png: 416x736 1 FireAlarm, 1 SafetySwitchPanel, 34.3ms
# image 270/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000183_light_unclutter.png: 416x736 4 OxygenTanks, 3 NitrogenTanks, 1 FirstAidBox, 34.3ms
# image 271/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000183_vdark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 272/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000183_vlight_unclutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 1 FirstAidBox, 1 SafetySwitchPanel, 1 EmergencyPhone, 34.4ms
# image 273/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000188_dark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 34.4ms
# image 274/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000188_vlight_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 275/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000189_dark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 1 SafetySwitchPanel, 34.3ms
# image 276/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000189_light_unclutter.png: 416x736 1 EmergencyPhone, 34.3ms
# image 277/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000189_vdark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 34.4ms
# image 278/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000189_vdark_unclutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 34.4ms
# image 279/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000191_vlight_unclutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 34.4ms
# image 280/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000192_vdark_clutter.png: 416x736 (no detections), 34.3ms
# image 281/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000193_vdark_clutter.png: 416x736 5 OxygenTanks, 3 NitrogenTanks, 1 FirstAidBox, 34.4ms
# image 282/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000194_vdark_clutter.png: 416x736 1 OxygenTank, 34.3ms
# image 283/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000194_vdark_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 284/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000195_dark_clutter.png: 416x736 3 OxygenTanks, 2 NitrogenTanks, 2 FirstAidBoxs, 2 FireExtinguishers, 34.4ms
# image 285/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000196_vdark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 1 FirstAidBox, 34.4ms
# image 286/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000197_dark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 287/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000197_vdark_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.4ms
# image 288/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000197_vlight_unclutter.png: 416x736 7 NitrogenTanks, 34.3ms
# image 289/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000200_dark_unclutter.png: 416x736 (no detections), 34.4ms
# image 290/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000200_vdark_unclutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 1 FirstAidBox, 34.4ms
# image 291/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000201_vdark_unclutter.png: 416x736 1 NitrogenTank, 1 FireAlarm, 34.3ms
# image 292/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000202_dark_clutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 293/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000203_vdark_clutter.png: 416x736 1 OxygenTank, 34.3ms
# image 294/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000204_dark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 34.3ms
# image 295/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000205_dark_unclutter.png: 416x736 1 FireAlarm, 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 296/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000205_vdark_clutter.png: 416x736 1 OxygenTank, 34.3ms
# image 297/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000205_vlight_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 298/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000206_light_unclutter.png: 416x736 2 OxygenTanks, 2 NitrogenTanks, 1 FirstAidBox, 34.3ms
# image 299/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000206_vlight_unclutter.png: 416x736 3 OxygenTanks, 5 NitrogenTanks, 3 FirstAidBoxs, 1 FireAlarm, 2 SafetySwitchPanels, 1 EmergencyPhone, 1 FireExtinguisher, 34.4ms
# image 300/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000208_dark_clutter.png: 416x736 3 FirstAidBoxs, 34.3ms
# image 301/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000208_dark_unclutter.png: 416x736 (no detections), 34.3ms
# image 302/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000209_dark_clutter.png: 416x736 5 OxygenTanks, 1 FireAlarm, 1 SafetySwitchPanel, 1 EmergencyPhone, 1 FireExtinguisher, 34.3ms
# image 303/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000209_dark_unclutter.png: 416x736 4 NitrogenTanks, 34.3ms
# image 304/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000210_dark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 305/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000210_vlight_unclutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 306/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000213_vdark_clutter.png: 416x736 1 NitrogenTank, 1 FireExtinguisher, 34.3ms
# image 307/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000214_dark_unclutter.png: 416x736 1 OxygenTank, 34.3ms
# image 308/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000215_vdark_clutter.png: 416x736 3 OxygenTanks, 1 FireExtinguisher, 34.3ms
# image 309/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000216_dark_clutter.png: 416x736 3 OxygenTanks, 1 NitrogenTank, 1 FirstAidBox, 1 SafetySwitchPanel, 2 FireExtinguishers, 34.3ms
# image 310/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000216_vdark_clutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 311/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000218_vdark_clutter.png: 416x736 3 OxygenTanks, 34.3ms
# image 312/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000220_dark_clutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 313/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000000220_vdark_clutter.png: 416x736 2 FirstAidBoxs, 34.3ms
# ...
# image 1305/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001657_dark_clutter.png: 416x736 1 OxygenTank, 34.3ms
# image 1306/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001658_dark_clutter.png: 416x736 1 OxygenTank, 34.3ms
# image 1307/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001659_dark_clutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 1308/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001659_light_unclutter.png: 416x736 1 FireExtinguisher, 34.4ms
# image 1309/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001663_dark_clutter.png: 416x736 3 OxygenTanks, 1 NitrogenTank, 1 FirstAidBox, 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 1310/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001664_light_unclutter.png: 416x736 1 OxygenTank, 4 NitrogenTanks, 2 FirstAidBoxs, 34.3ms
# image 1311/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001667_light_unclutter.png: 416x736 1 FireAlarm, 34.3ms
# image 1312/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001668_light_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 1313/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001672_light_unclutter.png: 416x736 3 OxygenTanks, 4 NitrogenTanks, 1 FireAlarm, 1 EmergencyPhone, 34.3ms
# image 1314/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001673_dark_clutter.png: 416x736 1 EmergencyPhone, 34.4ms
# image 1315/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001674_dark_clutter.png: 416x736 2 OxygenTanks, 3 NitrogenTanks, 34.4ms
# image 1316/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001674_light_unclutter.png: 416x736 1 FireAlarm, 1 EmergencyPhone, 34.4ms
# image 1317/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001675_dark_clutter.png: 416x736 2 OxygenTanks, 34.4ms
# image 1318/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001675_light_unclutter.png: 416x736 1 OxygenTank, 3 NitrogenTanks, 34.4ms
# image 1319/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001680_light_unclutter.png: 416x736 3 OxygenTanks, 3 NitrogenTanks, 34.3ms
# image 1320/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001683_dark_clutter.png: 416x736 2 OxygenTanks, 1 FireExtinguisher, 34.4ms
# image 1321/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001683_light_unclutter.png: 416x736 1 FirstAidBox, 34.3ms
# image 1322/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001684_light_unclutter.png: 416x736 3 OxygenTanks, 2 NitrogenTanks, 1 SafetySwitchPanel, 34.4ms
# image 1323/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001685_dark_clutter.png: 416x736 4 OxygenTanks, 34.3ms
# image 1324/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001685_light_unclutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 1325/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001686_light_unclutter.png: 416x736 4 OxygenTanks, 3 NitrogenTanks, 1 FirstAidBox, 34.4ms
# image 1326/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001687_light_unclutter.png: 416x736 3 OxygenTanks, 4 NitrogenTanks, 1 SafetySwitchPanel, 1 EmergencyPhone, 34.3ms
# image 1327/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001689_light_unclutter.png: 416x736 5 OxygenTanks, 5 NitrogenTanks, 2 FirstAidBoxs, 1 FireAlarm, 1 EmergencyPhone, 34.4ms
# image 1328/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001690_light_unclutter.png: 416x736 2 OxygenTanks, 2 FirstAidBoxs, 2 SafetySwitchPanels, 1 EmergencyPhone, 34.4ms
# image 1329/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001692_light_unclutter.png: 416x736 1 OxygenTank, 1 FireAlarm, 2 SafetySwitchPanels, 1 FireExtinguisher, 34.4ms
# image 1330/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001693_light_unclutter.png: 416x736 3 NitrogenTanks, 1 FirstAidBox, 34.4ms
# image 1331/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001694_dark_clutter.png: 416x736 1 FireExtinguisher, 34.4ms
# image 1332/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001695_dark_clutter.png: 416x736 1 OxygenTank, 3 NitrogenTanks, 3 FirstAidBoxs, 1 FireExtinguisher, 34.4ms
# image 1333/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001695_light_unclutter.png: 416x736 1 OxygenTank, 34.4ms
# image 1334/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001696_dark_clutter.png: 416x736 2 NitrogenTanks, 1 FireExtinguisher, 34.3ms
# image 1335/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001696_light_unclutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 1336/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001697_light_unclutter.png: 416x736 1 EmergencyPhone, 34.4ms
# image 1337/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001699_light_unclutter.png: 416x736 2 OxygenTanks, 2 NitrogenTanks, 34.4ms
# image 1338/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001701_light_unclutter.png: 416x736 1 NitrogenTank, 2 FirstAidBoxs, 34.3ms
# image 1339/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001704_light_unclutter.png: 416x736 1 OxygenTank, 2 NitrogenTanks, 1 FirstAidBox, 2 FireExtinguishers, 34.4ms
# image 1340/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001706_light_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 1341/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001707_dark_clutter.png: 416x736 1 OxygenTank, 34.4ms
# image 1342/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001711_light_unclutter.png: 416x736 1 NitrogenTank, 34.4ms
# image 1343/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001712_light_unclutter.png: 416x736 1 NitrogenTank, 1 FireExtinguisher, 34.4ms
# image 1344/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001713_dark_clutter.png: 416x736 2 OxygenTanks, 4 NitrogenTanks, 1 FirstAidBox, 4 FireExtinguishers, 34.3ms
# image 1345/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001714_light_unclutter.png: 416x736 1 NitrogenTank, 1 FireExtinguisher, 34.4ms
# image 1346/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001716_dark_clutter.png: 416x736 1 OxygenTank, 34.4ms
# image 1347/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001717_dark_clutter.png: 416x736 2 OxygenTanks, 34.3ms
# image 1348/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001718_dark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 1349/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001720_dark_clutter.png: 416x736 3 OxygenTanks, 34.3ms
# image 1350/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001720_light_unclutter.png: 416x736 2 OxygenTanks, 5 NitrogenTanks, 1 FirstAidBox, 2 FireAlarms, 1 EmergencyPhone, 1 FireExtinguisher, 34.4ms
# image 1351/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001722_dark_clutter.png: 416x736 1 OxygenTank, 2 NitrogenTanks, 2 FirstAidBoxs, 1 FireExtinguisher, 34.3ms
# image 1352/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001723_dark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 1 FireExtinguisher, 34.4ms
# image 1353/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001726_dark_clutter.png: 416x736 1 NitrogenTank, 34.4ms
# image 1354/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001727_dark_clutter.png: 416x736 1 FireExtinguisher, 34.4ms
# image 1355/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001736_light_unclutter.png: 416x736 (no detections), 34.4ms
# image 1356/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001738_light_unclutter.png: 416x736 1 FireExtinguisher, 34.4ms
# image 1357/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001739_dark_clutter.png: 416x736 1 OxygenTank, 34.4ms
# image 1358/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001740_light_unclutter.png: 416x736 4 OxygenTanks, 4 NitrogenTanks, 1 FireAlarm, 1 SafetySwitchPanel, 34.3ms
# image 1359/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001742_dark_clutter.png: 416x736 1 OxygenTank, 34.4ms
# image 1360/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001744_light_unclutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 34.3ms
# image 1361/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001745_dark_clutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 2 FirstAidBoxs, 1 SafetySwitchPanel, 2 FireExtinguishers, 34.4ms
# image 1362/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001750_dark_clutter.png: 416x736 2 NitrogenTanks, 1 FirstAidBox, 34.4ms
# image 1363/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001753_dark_clutter.png: 416x736 1 OxygenTank, 1 FirstAidBox, 1 SafetySwitchPanel, 1 FireExtinguisher, 34.3ms
# image 1364/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001754_light_unclutter.png: 416x736 6 OxygenTanks, 8 NitrogenTanks, 4 FirstAidBoxs, 2 FireAlarms, 3 SafetySwitchPanels, 1 EmergencyPhone, 34.3ms
# image 1365/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001758_dark_clutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 1366/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001761_dark_clutter.png: 416x736 2 OxygenTanks, 1 FireExtinguisher, 34.4ms
# image 1367/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001761_light_unclutter.png: 416x736 1 SafetySwitchPanel, 34.4ms
# image 1368/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001762_dark_clutter.png: 416x736 2 OxygenTanks, 1 NitrogenTank, 34.3ms
# image 1369/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001763_dark_clutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 1370/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001766_light_unclutter.png: 416x736 1 OxygenTank, 1 FireAlarm, 34.3ms
# image 1371/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001768_light_unclutter.png: 416x736 1 SafetySwitchPanel, 34.4ms
# image 1372/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001769_light_unclutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 1373/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001772_dark_clutter.png: 416x736 1 FireExtinguisher, 34.3ms
# image 1374/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001772_light_unclutter.png: 416x736 2 FirstAidBoxs, 34.3ms
# image 1375/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001773_dark_clutter.png: 416x736 1 FirstAidBox, 34.4ms
# image 1376/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001774_dark_clutter.png: 416x736 1 NitrogenTank, 34.4ms
# image 1377/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001776_dark_clutter.png: 416x736 4 OxygenTanks, 2 FirstAidBoxs, 1 FireExtinguisher, 34.4ms
# image 1378/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001777_dark_clutter.png: 416x736 1 NitrogenTank, 1 FireExtinguisher, 34.3ms
# image 1379/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001781_dark_clutter.png: 416x736 1 SafetySwitchPanel, 34.3ms
# image 1380/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001782_light_unclutter.png: 416x736 1 FireExtinguisher, 34.4ms
# image 1381/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001783_dark_clutter.png: 416x736 1 OxygenTank, 34.3ms
# image 1382/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001785_light_unclutter.png: 416x736 2 FirstAidBoxs, 2 FireExtinguishers, 34.4ms
# image 1383/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001791_light_unclutter.png: 416x736 3 OxygenTanks, 3 NitrogenTanks, 1 FireExtinguisher, 34.4ms
# image 1384/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001793_light_unclutter.png: 416x736 1 FireAlarm, 1 SafetySwitchPanel, 1 EmergencyPhone, 34.4ms
# image 1385/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001794_light_unclutter.png: 416x736 4 OxygenTanks, 1 NitrogenTank, 1 FireExtinguisher, 34.3ms
# image 1386/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001795_light_unclutter.png: 416x736 1 FireExtinguisher, 34.4ms
# image 1387/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001807_light_unclutter.png: 416x736 1 OxygenTank, 4 NitrogenTanks, 34.4ms
# image 1388/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001810_light_unclutter.png: 416x736 1 SafetySwitchPanel, 34.4ms
# image 1389/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001817_light_unclutter.png: 416x736 3 OxygenTanks, 4 NitrogenTanks, 1 FirstAidBox, 2 FireAlarms, 1 EmergencyPhone, 34.4ms
# image 1390/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001821_light_unclutter.png: 416x736 1 OxygenTank, 34.4ms
# image 1391/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001823_light_unclutter.png: 416x736 2 NitrogenTanks, 1 FirstAidBox, 1 SafetySwitchPanel, 34.4ms
# image 1392/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001825_light_unclutter.png: 416x736 1 OxygenTank, 4 NitrogenTanks, 34.4ms
# image 1393/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001828_light_unclutter.png: 416x736 1 SafetySwitchPanel, 34.4ms
# image 1394/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001829_light_unclutter.png: 416x736 2 OxygenTanks, 2 NitrogenTanks, 1 FirstAidBox, 3 SafetySwitchPanels, 1 FireExtinguisher, 34.3ms
# image 1395/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001832_light_unclutter.png: 416x736 4 NitrogenTanks, 34.4ms
# image 1396/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001834_light_unclutter.png: 416x736 1 FireAlarm, 34.4ms
# image 1397/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001835_light_unclutter.png: 416x736 2 FireExtinguishers, 34.4ms
# image 1398/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001842_light_unclutter.png: 416x736 1 SafetySwitchPanel, 34.4ms
# image 1399/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001843_light_unclutter.png: 416x736 1 OxygenTank, 1 NitrogenTank, 34.4ms
# image 1400/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001844_light_unclutter.png: 416x736 1 NitrogenTank, 34.4ms
# image 1401/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001845_light_unclutter.png: 416x736 2 OxygenTanks, 4 NitrogenTanks, 34.4ms
# image 1402/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001849_light_unclutter.png: 416x736 1 NitrogenTank, 34.3ms
# image 1403/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001851_light_unclutter.png: 416x736 1 FireExtinguisher, 34.3ms
# image 1404/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001857_light_unclutter.png: 416x736 1 FireAlarm, 34.3ms
# image 1405/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001860_light_unclutter.png: 416x736 1 FirstAidBox, 34.4ms
# image 1406/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001862_light_unclutter.png: 416x736 1 NitrogenTank, 1 FirstAidBox, 1 FireExtinguisher, 34.3ms
# image 1407/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001864_light_unclutter.png: 416x736 1 FireAlarm, 34.4ms
# image 1408/1408 /kaggle/input/duality-ai/Hackathon2_test1/test1/images/000001873_light_unclutter.png: 416x736 2 OxygenTanks, 3 NitrogenTanks, 1 FirstAidBox, 3 FireAlarms, 1 SafetySwitchPanel, 1 FireExtinguisher, 34.3ms
# Speed: 2.5ms preprocess, 34.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 736)
# Results saved to /kaggle/working/space_mission/test_predictions
# 1356 labels saved to /kaggle/working/space_mission/test_predictions/labels
# ✅ Testing complete! Results saved to: /kaggle/working/space_mission/test_predictions

# %%
! nvidia-smi
# Out:
# Fri Dec 19 17:30:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0             32W /  250W |   16267MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
# EPOCHS = 10
# MOSAIC = 0.4
# OPTIMIZER = 'AdamW'
# MOMENTUM = 0.9
# LR0 = 0.0001
# LRF = 0.0001
# SINGLE_CLS = False
# import argparse
# from ultralytics import YOLO
# import os
# import sys

# if __name__ == '__main__': 
#     parser = argparse.ArgumentParser()
#     # epochs
#     parser.add_argument('--epochs', type=int, default=EPOCHS, help='Number of epochs')
#     # mosaic
#     parser.add_argument('--mosaic', type=float, default=MOSAIC, help='Mosaic augmentation')
#     # optimizer
#     parser.add_argument('--optimizer', type=str, default=OPTIMIZER, help='Optimizer')
#     # momentum
#     parser.add_argument('--momentum', type=float, default=MOMENTUM, help='Momentum')
#     # lr0
#     parser.add_argument('--lr0', type=float, default=LR0, help='Initial learning rate')
#     # lrf
#     parser.add_argument('--lrf', type=float, default=LRF, help='Final learning rate')
#     # single_cls
#     parser.add_argument('--single_cls', type=bool, default=SINGLE_CLS, help='Single class training')
#     args, unknown = parser.parse_known_args()
    
   
#     model = YOLO("yolov8s.pt")
#     results = model.train(
#         data=yaml_path, 
#         epochs=args.epochs,
#         device=0,
#         single_cls=args.single_cls, 
#         mosaic=args.mosaic,
#         optimizer=args.optimizer, 
#         lr0 = args.lr0, 
#         lrf = args.lrf, 
#         momentum=args.momentum
#     )
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 169.2MB/s 0.1s0.1s<0.1s
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/space-dataset/yolo_params.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0001, lrf=0.0001, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.9, mosaic=0.4, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2118757  ultralytics.nn.modules.head.Detect           [7, [128, 256, 512]]
# Model summary: 129 layers, 11,138,309 parameters, 11,138,293 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 63.3MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4739.7±1157.9 MB/s, size: 3064.1 KB)
# train: Scanning /kaggle/working/space-dataset/train/labels... 1767 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1767/1767 388.1it/s 4.6s0.1s
# train: New cache created: /kaggle/working/space-dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2454.2±1735.8 MB/s, size: 2778.1 KB)
# val: Scanning /kaggle/working/space-dataset/val/labels... 336 images, 16 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 336/336 323.6it/s 1.0s<0.0s
# val: New cache created: /kaggle/working/space-dataset/val/labels.cache
# Plotting labels to /kaggle/working/runs/detect/train/labels.jpg...
# optimizer: AdamW(lr=0.0001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      3.74G     0.9498      3.112      1.117         14        640: 100% ━━━━━━━━━━━━ 111/111 1.6it/s 1:080.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.0it/s 5.6s0.3s
#                    all        336        957      0.556      0.416       0.43      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      3.97G     0.7929      1.213      1.007         14        640: 100% ━━━━━━━━━━━━ 111/111 1.7it/s 1:040.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.3it/s 4.7s0.3s
#                    all        336        957      0.679      0.475      0.544      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      4.01G     0.7036     0.9506     0.9585         28        640: 100% ━━━━━━━━━━━━ 111/111 1.7it/s 1:040.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.3it/s 4.8s0.4s
#                    all        336        957      0.661      0.602      0.639      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      4.05G     0.6527     0.8177     0.9381         11        640: 100% ━━━━━━━━━━━━ 111/111 1.7it/s 1:050.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.3it/s 4.7s0.4s
#                    all        336        957       0.75      0.634      0.688      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      4.08G     0.6273     0.7189     0.9225         12        640: 100% ━━━━━━━━━━━━ 111/111 1.7it/s 1:050.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.3it/s 4.8s0.3s
#                    all        336        957       0.87      0.615      0.721      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      4.11G     0.5978     0.6719     0.9029         13        640: 100% ━━━━━━━━━━━━ 111/111 1.7it/s 1:040.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.4it/s 4.5s0.4s
#                    all        336        957      0.822      0.652      0.737      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      4.15G     0.5758     0.6048     0.8929         21        640: 100% ━━━━━━━━━━━━ 111/111 1.7it/s 1:050.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.4it/s 4.5s0.4s
#                    all        336        957      0.824      0.682      0.749      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      4.19G     0.5563     0.5853     0.8889         47        640: 100% ━━━━━━━━━━━━ 111/111 1.7it/s 1:050.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.5it/s 4.5s0.3s
#                    all        336        957      0.841      0.685      0.752      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      4.22G     0.5404     0.5516     0.8785         19        640: 100% ━━━━━━━━━━━━ 111/111 1.7it/s 1:040.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.3it/s 4.8s0.3s
#                    all        336        957      0.881      0.671       0.76      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      4.26G     0.5287     0.5187     0.8755         12        640: 100% ━━━━━━━━━━━━ 111/111 1.7it/s 1:040.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 2.4it/s 4.5s0.3s
#                    all        336        957      0.896      0.668      0.765      0.633
#
# 10 epochs completed in 0.196 hours.
# Optimizer stripped from /kaggle/working/runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from /kaggle/working/runs/detect/train/weights/best.pt, 22.5MB
#
# Validating /kaggle/working/runs/detect/train/weights/best.pt...
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 1.2it/s 9.1s1.0s
#                    all        336        957      0.896      0.668      0.765      0.633
#             OxygenTank        135        237      0.937      0.785      0.861      0.764
#           NitrogenTank        157        283      0.886      0.689      0.813        0.7
#            FirstAidBox         97        119      0.879      0.731      0.827      0.723
#              FireAlarm         55         57      0.953      0.718       0.83      0.696
#      SafetySwitchPanel         55         60      0.842      0.633      0.674      0.505
#         EmergencyPhone         60         69      0.948      0.478      0.628      0.464
#       FireExtinguisher         92        132      0.827      0.644       0.72      0.578
# Speed: 0.1ms preprocess, 2.6ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train
